# %%
import numpy as np
import pandas as pd

# Ignore Warning Code
import warnings
warnings.filterwarnings('ignore')

# %%
file_path = "/Users/igmark/Desktop/DS4A_Data/2021OwnershipPaymentData.csv"
df = pd.read_csv(file_path, nrows=10000)

# %%
df
# Out:
#      Change_Type  Physician_Profile_ID  Physician_NPI Physician_First_Name  \
# 0      UNCHANGED                161867   1.568413e+09          Christopher
# 1      UNCHANGED                161599   1.578583e+09              William
# 2      UNCHANGED                  2198   1.053398e+09                 John
# 3      UNCHANGED                267325   1.891892e+09                DAVID
# 4      UNCHANGED               1179193   1.669403e+09               Daniel
# ...          ...                   ...            ...                  ...
# 3124   UNCHANGED               2792709   1.487974e+09                Ralph
# 3125   UNCHANGED                141844   1.134331e+09               Ernest
# 3126   UNCHANGED                 26502   1.578761e+09          Jane-Claire
# 3127   UNCHANGED                 98438   1.184612e+09                 Mark
# 3128   UNCHANGED                199913   1.417946e+09              Cynthia
#
#      Physician_Middle_Name Physician_Last_Name Physician_Name_Suffix  \
# 0                      NaN              Coogan                   NaN
# 1                      NaN                Cook                   NaN
# 2                        J             Cudecki                   NaN
# 3                        L          CUNNINGHAM                   NaN
# 4                      NaN              Dalton                   NaN
# ...                    ...                 ...                   ...
# 3124                Brooks               Vance                    Jr
# 3125              Stephens               Weeks                   NaN
# 3126                   NaN            Williams                   NaN
# 3127                     E              Wilson                   NaN
# 3128                 Haden              Wright                   NaN
#
#      Recipient_Primary_Business_Street_Address_Line1  \
# 0                                 1725 W Harrison St
# 1                       10901 East 48th Street South
# 2                                  2850 S Wabash Ave
# 3                              12109 County Road 103
# 4                                     676 N St Clair
# ...                                              ...
# 3124                                2510 Lakeland Dr
# 3125                                2510 Lakeland Dr
# 3126                                2510 Lakeland Dr
# 3127                                2510 Lakeland Dr
# 3128                                2510 Lakeland Dr
#
#      Recipient_Primary_Business_Street_Address_Line2 Recipient_City  ...  \
# 0                                          Suite 758        Chicago  ...
# 1                                                NaN          Tulsa  ...
# 2                                          Suite 106        Chicago  ...
# 3                                                NaN         Oxford  ...
# 4                                         Suite 1835        Chicago  ...
# ...                                              ...            ...  ...
# 3124                                             NaN        Flowood  ...
# 3125                                             NaN        Flowood  ...
# 3126                                             NaN        Flowood  ...
# 3127                                             NaN        Flowood  ...
# 3128                                             NaN        Flowood  ...
#
#      Value_of_Interest Terms_of_Interest  \
# 0             33125.17      Common Stock
# 1             33125.46      Common Stock
# 2             33125.17      Common Stock
# 3              6436.16      Common Stock
# 4             33125.17      Common Stock
# ...                ...               ...
# 3124            631.60      Common Stock
# 3125            947.40      Common Stock
# 3126           1579.00      Common Stock
# 3127           1263.20      Common Stock
# 3128           1894.80      Common Stock
#
#      Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name  \
# 0                                      SN Holdings, LLC
# 1                                      SN Holdings, LLC
# 2                                      SN Holdings, LLC
# 3                                      SN Holdings, LLC
# 4                                      SN Holdings, LLC
# ...                                                 ...
# 3124                                     GastroGPO, LLC
# 3125                                     GastroGPO, LLC
# 3126                                     GastroGPO, LLC
# 3127                                     GastroGPO, LLC
# 3128                                     GastroGPO, LLC
#
#       Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID  \
# 0                                          100000876822
# 1                                          100000876822
# 2                                          100000876822
# 3                                          100000876822
# 4                                          100000876822
# ...                                                 ...
# 3124                                       100000961861
# 3125                                       100000961861
# 3126                                       100000961861
# 3127                                       100000961861
# 3128                                       100000961861
#
#       Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name  \
# 0                                      SN Holdings, LLC
# 1                                      SN Holdings, LLC
# 2                                      SN Holdings, LLC
# 3                                      SN Holdings, LLC
# 4                                      SN Holdings, LLC
# ...                                                 ...
# 3124                                     GastroGPO, LLC
# 3125                                     GastroGPO, LLC
# 3126                                     GastroGPO, LLC
# 3127                                     GastroGPO, LLC
# 3128                                     GastroGPO, LLC
#
#      Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State  \
# 0                                                    OH
# 1                                                    OH
# 2                                                    OH
# 3                                                    OH
# 4                                                    OH
# ...                                                 ...
# 3124                                                 OH
# 3125                                                 OH
# 3126                                                 OH
# 3127                                                 OH
# 3128                                                 OH
#
#      Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country  \
# 0                                         United States
# 1                                         United States
# 2                                         United States
# 3                                         United States
# 4                                         United States
# ...                                                 ...
# 3124                                      United States
# 3125                                      United States
# 3126                                      United States
# 3127                                      United States
# 3128                                      United States
#
#       Dispute_Status_for_Publication  \
# 0                                 No
# 1                                 No
# 2                                 No
# 3                                 No
# 4                                 No
# ...                              ...
# 3124                              No
# 3125                              No
# 3126                              No
# 3127                              No
# 3128                              No
#
#       Interest_Held_by_Physician_or_an_Immediate_Family_Member  \
# 0                           Physician Covered Recipient
# 1                           Physician Covered Recipient
# 2                           Physician Covered Recipient
# 3                           Physician Covered Recipient
# 4                           Physician Covered Recipient
# ...                                                 ...
# 3124                        Physician Covered Recipient
# 3125                        Physician Covered Recipient
# 3126                        Physician Covered Recipient
# 3127                        Physician Covered Recipient
# 3128                        Physician Covered Recipient
#
#       Payment_Publication_Date
# 0                   01/20/2023
# 1                   01/20/2023
# 2                   01/20/2023
# 3                   01/20/2023
# 4                   01/20/2023
# ...                        ...
# 3124                01/20/2023
# 3125                01/20/2023
# 3126                01/20/2023
# 3127                01/20/2023
# 3128                01/20/2023
#
# [3129 rows x 30 columns]

# %%
df.info(file_path)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 30 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Change_Type                                                       3129 non-null   object
#  1   Physician_Profile_ID                                              3129 non-null   int64
#  2   Physician_NPI                                                     3127 non-null   float64
#  3   Physician_First_Name                                              3129 non-null   object
#  4   Physician_Middle_Name                                             1429 non-null   object
#  5   Physician_Last_Name                                               3129 non-null   object
#  6   Physician_Name_Suffix                                             322 non-null    object
#  7   Recipient_Primary_Business_Street_Address_Line1                   3129 non-null   object
#  8   Recipient_Primary_Business_Street_Address_Line2                   1094 non-null   object
#  9   Recipient_City                                                    3129 non-null   object
#  10  Recipient_State                                                   3129 non-null   object
#  11  Recipient_Zip_Code                                                3129 non-null   object
#  12  Recipient_Country                                                 3129 non-null   object
#  13  Recipient_Province                                                0 non-null      float64
#  14  Recipient_Postal_Code                                             0 non-null      float64
#  15  Physician_Primary_Type                                            3129 non-null   object
#  16  Physician_Specialty                                               3037 non-null   object
#  17  Record_ID                                                         3129 non-null   int64
#  18  Program_Year                                                      3129 non-null   int64
#  19  Total_Amount_Invested_USDollars                                   3129 non-null   float64
#  20  Value_of_Interest                                                 3129 non-null   float64
#  21  Terms_of_Interest                                                 3128 non-null   object
#  22  Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name         3129 non-null   object
#  23  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID       3129 non-null   int64
#  24  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name     3129 non-null   object
#  25  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State    3100 non-null   object
#  26  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country  3129 non-null   object
#  27  Dispute_Status_for_Publication                                    3129 non-null   object
#  28  Interest_Held_by_Physician_or_an_Immediate_Family_Member          3129 non-null   object
#  29  Payment_Publication_Date                                          3129 non-null   object
# dtypes: float64(5), int64(4), object(21)
# memory usage: 733.5+ KB

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3124    False
# 3125    False
# 3126    False
# 3127    False
# 3128    False
# Length: 3129, dtype: bool

# %%
df.isnull().sum()
# Out:
# Change_Type                                                            0
# Physician_Profile_ID                                                   0
# Physician_NPI                                                          2
# Physician_First_Name                                                   0
# Physician_Middle_Name                                               1700
# Physician_Last_Name                                                    0
# Physician_Name_Suffix                                               2807
# Recipient_Primary_Business_Street_Address_Line1                        0
# Recipient_Primary_Business_Street_Address_Line2                     2035
# Recipient_City                                                         0
# Recipient_State                                                        0
# Recipient_Zip_Code                                                     0
# Recipient_Country                                                      0
# Recipient_Province                                                  3129
# Recipient_Postal_Code                                               3129
# Physician_Primary_Type                                                 0
# Physician_Specialty                                                   92
# Record_ID                                                              0
# Program_Year                                                           0
# Total_Amount_Invested_USDollars                                        0
# Value_of_Interest                                                      0
# Terms_of_Interest                                                      1
# Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name              0
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID            0
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name          0
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State        29
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country       0
# Dispute_Status_for_Publication                                         0
# Interest_Held_by_Physician_or_an_Immediate_Family_Member               0
# Payment_Publication_Date                                               0
# dtype: int64

# %%
df.drop(columns=['Physician_Name_Suffix', 'Recipient_Primary_Business_Street_Address_Line1',
                'Recipient_Primary_Business_Street_Address_Line2', 'Physician_Middle_Name','Recipient_Country', 'Recipient_Province', 
                 'Recipient_Postal_Code'], inplace=True)

# %%
df.info(file_path)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 23 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Change_Type                                                       3129 non-null   object
#  1   Physician_Profile_ID                                              3129 non-null   int64
#  2   Physician_NPI                                                     3127 non-null   float64
#  3   Physician_First_Name                                              3129 non-null   object
#  4   Physician_Last_Name                                               3129 non-null   object
#  5   Recipient_City                                                    3129 non-null   object
#  6   Recipient_State                                                   3129 non-null   object
#  7   Recipient_Zip_Code                                                3129 non-null   object
#  8   Physician_Primary_Type                                            3129 non-null   object
#  9   Physician_Specialty                                               3037 non-null   object
#  10  Record_ID                                                         3129 non-null   int64
#  11  Program_Year                                                      3129 non-null   int64
#  12  Total_Amount_Invested_USDollars                                   3129 non-null   float64
#  13  Value_of_Interest                                                 3129 non-null   float64
#  14  Terms_of_Interest                                                 3128 non-null   object
#  15  Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name         3129 non-null   object
#  16  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID       3129 non-null   int64
#  17  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name     3129 non-null   object
#  18  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State    3100 non-null   object
#  19  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country  3129 non-null   object
#  20  Dispute_Status_for_Publication                                    3129 non-null   object
#  21  Interest_Held_by_Physician_or_an_Immediate_Family_Member          3129 non-null   object
#  22  Payment_Publication_Date                                          3129 non-null   object
# dtypes: float64(3), int64(4), object(16)
# memory usage: 562.4+ KB

# %%
df.columns
# Out:
# Index(['Change_Type', 'Physician_Profile_ID', 'Physician_NPI',
#        'Physician_First_Name', 'Physician_Last_Name', 'Recipient_City',
#        'Recipient_State', 'Recipient_Zip_Code', 'Physician_Primary_Type',
#        'Physician_Specialty', 'Record_ID', 'Program_Year',
#        'Total_Amount_Invested_USDollars', 'Value_of_Interest',
#        'Terms_of_Interest',
#        'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
#        'Dispute_Status_for_Publication',
#        'Interest_Held_by_Physician_or_an_Immediate_Family_Member',
#        'Payment_Publication_Date'],
#       dtype='object')

# %%
 df.isnull().sum()
# Out:
# Change_Type                                                          0
# Physician_Profile_ID                                                 0
# Physician_NPI                                                        2
# Physician_First_Name                                                 0
# Physician_Last_Name                                                  0
# Recipient_City                                                       0
# Recipient_State                                                      0
# Recipient_Zip_Code                                                   0
# Physician_Primary_Type                                               0
# Physician_Specialty                                                 92
# Record_ID                                                            0
# Program_Year                                                         0
# Total_Amount_Invested_USDollars                                      0
# Value_of_Interest                                                    0
# Terms_of_Interest                                                    1
# Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name            0
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID          0
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name        0
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State      29
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country     0
# Dispute_Status_for_Publication                                       0
# Interest_Held_by_Physician_or_an_Immediate_Family_Member             0
# Payment_Publication_Date                                             0
# dtype: int64

# %%
df['Physician_NPI'] = df['Physician_NPI'].astype('object')

# %%
df['Recipient_Zip_Code'] = df['Recipient_Zip_Code'].astype(str).str[:5]

# %%
print(df['Recipient_Zip_Code'])
# Out:
# 0       60612
# 1       74146
# 2       60616
# 3       34484
# 4       60611
#         ...
# 3124    39232
# 3125    39232
# 3126    39232
# 3127    39232
# 3128    39232
# Name: Recipient_Zip_Code, Length: 3129, dtype: object

# %%
df['Total_Amount_Invested_USDollars'] = df['Total_Amount_Invested_USDollars'].round(2)

# %%
print(df['Total_Amount_Invested_USDollars'])
# Out:
# 0          0.00
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.00
#          ...
# 3124     505.14
# 3125     757.71
# 3126    1262.85
# 3127    1010.28
# 3128    1515.43
# Name: Total_Amount_Invested_USDollars, Length: 3129, dtype: float64

# %%
df['Value_of_Interest'] = df['Value_of_Interest'].astype(int)

# %%
df.fillna("Not available", inplace=True)

# %%
df
# Out:
#      Change_Type  Physician_Profile_ID Physician_NPI Physician_First_Name  \
# 0      UNCHANGED                161867  1568412716.0          Christopher
# 1      UNCHANGED                161599  1578583423.0              William
# 2      UNCHANGED                  2198  1053397851.0                 John
# 3      UNCHANGED                267325  1891891594.0                DAVID
# 4      UNCHANGED               1179193  1669403432.0               Daniel
# ...          ...                   ...           ...                  ...
# 3124   UNCHANGED               2792709  1487974192.0                Ralph
# 3125   UNCHANGED                141844  1134330822.0               Ernest
# 3126   UNCHANGED                 26502  1578760534.0          Jane-Claire
# 3127   UNCHANGED                 98438  1184612368.0                 Mark
# 3128   UNCHANGED                199913  1417945668.0              Cynthia
#
#      Physician_Last_Name Recipient_City Recipient_State Recipient_Zip_Code  \
# 0                 Coogan        Chicago              IL              60612
# 1                   Cook          Tulsa              OK              74146
# 2                Cudecki        Chicago              IL              60616
# 3             CUNNINGHAM         Oxford              FL              34484
# 4                 Dalton        Chicago              IL              60611
# ...                  ...            ...             ...                ...
# 3124               Vance        Flowood              MS              39232
# 3125               Weeks        Flowood              MS              39232
# 3126            Williams        Flowood              MS              39232
# 3127              Wilson        Flowood              MS              39232
# 3128              Wright        Flowood              MS              39232
#
#      Physician_Primary_Type  \
# 0            Medical Doctor
# 1            Medical Doctor
# 2            Medical Doctor
# 3            Medical Doctor
# 4            Medical Doctor
# ...                     ...
# 3124         Medical Doctor
# 3125         Medical Doctor
# 3126         Medical Doctor
# 3127         Medical Doctor
# 3128         Medical Doctor
#
#                                     Physician_Specialty  ...  \
# 0           Allopathic & Osteopathic Physicians|Urology  ...
# 1           Allopathic & Osteopathic Physicians|Urology  ...
# 2           Allopathic & Osteopathic Physicians|Urology  ...
# 3           Allopathic & Osteopathic Physicians|Urology  ...
# 4           Allopathic & Osteopathic Physicians|Urology  ...
# ...                                                 ...  ...
# 3124  Allopathic & Osteopathic Physicians|Internal M...  ...
# 3125  Allopathic & Osteopathic Physicians|Internal M...  ...
# 3126  Allopathic & Osteopathic Physicians|Internal M...  ...
# 3127  Allopathic & Osteopathic Physicians|Internal M...  ...
# 3128  Allopathic & Osteopathic Physicians|Internal M...  ...
#
#       Value_of_Interest  Terms_of_Interest  \
# 0                 33125       Common Stock
# 1                 33125       Common Stock
# 2                 33125       Common Stock
# 3                  6436       Common Stock
# 4                 33125       Common Stock
# ...                 ...                ...
# 3124                631       Common Stock
# 3125                947       Common Stock
# 3126               1579       Common Stock
# 3127               1263       Common Stock
# 3128               1894       Common Stock
#
#       Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name  \
# 0                                      SN Holdings, LLC
# 1                                      SN Holdings, LLC
# 2                                      SN Holdings, LLC
# 3                                      SN Holdings, LLC
# 4                                      SN Holdings, LLC
# ...                                                 ...
# 3124                                     GastroGPO, LLC
# 3125                                     GastroGPO, LLC
# 3126                                     GastroGPO, LLC
# 3127                                     GastroGPO, LLC
# 3128                                     GastroGPO, LLC
#
#       Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID  \
# 0                                          100000876822
# 1                                          100000876822
# 2                                          100000876822
# 3                                          100000876822
# 4                                          100000876822
# ...                                                 ...
# 3124                                       100000961861
# 3125                                       100000961861
# 3126                                       100000961861
# 3127                                       100000961861
# 3128                                       100000961861
#
#      Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name  \
# 0                                      SN Holdings, LLC
# 1                                      SN Holdings, LLC
# 2                                      SN Holdings, LLC
# 3                                      SN Holdings, LLC
# 4                                      SN Holdings, LLC
# ...                                                 ...
# 3124                                     GastroGPO, LLC
# 3125                                     GastroGPO, LLC
# 3126                                     GastroGPO, LLC
# 3127                                     GastroGPO, LLC
# 3128                                     GastroGPO, LLC
#
#      Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State  \
# 0                                                    OH
# 1                                                    OH
# 2                                                    OH
# 3                                                    OH
# 4                                                    OH
# ...                                                 ...
# 3124                                                 OH
# 3125                                                 OH
# 3126                                                 OH
# 3127                                                 OH
# 3128                                                 OH
#
#       Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country  \
# 0                                         United States
# 1                                         United States
# 2                                         United States
# 3                                         United States
# 4                                         United States
# ...                                                 ...
# 3124                                      United States
# 3125                                      United States
# 3126                                      United States
# 3127                                      United States
# 3128                                      United States
#
#      Dispute_Status_for_Publication  \
# 0                                No
# 1                                No
# 2                                No
# 3                                No
# 4                                No
# ...                             ...
# 3124                             No
# 3125                             No
# 3126                             No
# 3127                             No
# 3128                             No
#
#      Interest_Held_by_Physician_or_an_Immediate_Family_Member  \
# 0                           Physician Covered Recipient
# 1                           Physician Covered Recipient
# 2                           Physician Covered Recipient
# 3                           Physician Covered Recipient
# 4                           Physician Covered Recipient
# ...                                                 ...
# 3124                        Physician Covered Recipient
# 3125                        Physician Covered Recipient
# 3126                        Physician Covered Recipient
# 3127                        Physician Covered Recipient
# 3128                        Physician Covered Recipient
#
#      Payment_Publication_Date
# 0                  01/20/2023
# 1                  01/20/2023
# 2                  01/20/2023
# 3                  01/20/2023
# 4                  01/20/2023
# ...                       ...
# 3124               01/20/2023
# 3125               01/20/2023
# 3126               01/20/2023
# 3127               01/20/2023
# 3128               01/20/2023
#
# [3129 rows x 23 columns]

# %%
df.info(file_path)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 23 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Change_Type                                                       3129 non-null   object
#  1   Physician_Profile_ID                                              3129 non-null   int64
#  2   Physician_NPI                                                     3129 non-null   object
#  3   Physician_First_Name                                              3129 non-null   object
#  4   Physician_Last_Name                                               3129 non-null   object
#  5   Recipient_City                                                    3129 non-null   object
#  6   Recipient_State                                                   3129 non-null   object
#  7   Recipient_Zip_Code                                                3129 non-null   object
#  8   Physician_Primary_Type                                            3129 non-null   object
#  9   Physician_Specialty                                               3129 non-null   object
#  10  Record_ID                                                         3129 non-null   int64
#  11  Program_Year                                                      3129 non-null   int64
#  12  Total_Amount_Invested_USDollars                                   3129 non-null   float64
#  13  Value_of_Interest                                                 3129 non-null   int64
#  14  Terms_of_Interest                                                 3129 non-null   object
#  15  Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name         3129 non-null   object
#  16  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID       3129 non-null   int64
#  17  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name     3129 non-null   object
#  18  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State    3129 non-null   object
#  19  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country  3129 non-null   object
#  20  Dispute_Status_for_Publication                                    3129 non-null   object
#  21  Interest_Held_by_Physician_or_an_Immediate_Family_Member          3129 non-null   object
#  22  Payment_Publication_Date                                          3129 non-null   object
# dtypes: float64(1), int64(5), object(17)
# memory usage: 562.4+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a correlation matrix
corr_matrix = df.corr()

# Create a heatmap using seaborn
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')

# Show the plot
plt.show()

# %%
df.boxplot(figsize = (15,15))
# Out:
# <AxesSubplot: >

# %%
df.hist(figsize = (15,15))
# Out:
# array([[<AxesSubplot: title={'center': 'Physician_Profile_ID'}>,
#         <AxesSubplot: title={'center': 'Record_ID'}>],
#        [<AxesSubplot: title={'center': 'Program_Year'}>,
#         <AxesSubplot: title={'center': 'Total_Amount_Invested_USDollars'}>],
#        [<AxesSubplot: title={'center': 'Value_of_Interest'}>,
#         <AxesSubplot: title={'center': 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID'}>]],
#       dtype=object)

# %%
#check for outliers and remove
from scipy import stats

print(df.shape)
df = df[(np.abs(stats.zscore(df.select_dtypes(include=np.number))) < 3).all(axis=1)]
print(df.shape)
# Out:
# (3129, 23)
# (0, 23)

# %%
#Save to new file 
df.to_csv('2021OwnershipPaymentData_prepared.csv')
