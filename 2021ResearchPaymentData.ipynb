# %%
import numpy as np
import pandas as pd

# Ignore Warning Code
import warnings
warnings.filterwarnings('ignore')

# %%
file_path = "/Users/igmark/Desktop/DS4A_Data/2021ResearchPaymentData.csv"
df = pd.read_csv(file_path, nrows=10000)

# %%
df
# Out:
#      Change_Type               Covered_Recipient_Type  \
# 0      UNCHANGED  Covered Recipient Teaching Hospital
# 1      UNCHANGED  Covered Recipient Teaching Hospital
# 2      UNCHANGED  Covered Recipient Teaching Hospital
# 3      UNCHANGED  Covered Recipient Teaching Hospital
# 4      UNCHANGED  Covered Recipient Teaching Hospital
# ...          ...                                  ...
# 9995   UNCHANGED  Covered Recipient Teaching Hospital
# 9996   UNCHANGED  Covered Recipient Teaching Hospital
# 9997   UNCHANGED  Covered Recipient Teaching Hospital
# 9998   UNCHANGED  Covered Recipient Teaching Hospital
# 9999   UNCHANGED  Covered Recipient Teaching Hospital
#
#       Noncovered_Recipient_Entity_Name  Teaching_Hospital_CCN  \
# 0                                  NaN               230297.0
# 1                                  NaN               363300.0
# 2                                  NaN               140127.0
# 3                                  NaN                50696.0
# ...

# %%
df.info(file_path)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 252 columns):
#  #    Column                                                            Dtype
# ---   ------                                                            -----
#  0    Change_Type                                                       object
#  1    Covered_Recipient_Type                                            object
#  2    Noncovered_Recipient_Entity_Name                                  float64
#  3    Teaching_Hospital_CCN                                             float64
#  4    Teaching_Hospital_ID                                              float64
#  5    Teaching_Hospital_Name                                            object
#  6    Covered_Recipient_Profile_ID                                      float64
#  7    Covered_Recipient_NPI                                             float64
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.isnull().sum()
# Out:
# Change_Type                             0
# Covered_Recipient_Type                  0
# Noncovered_Recipient_Entity_Name    10000
# Teaching_Hospital_CCN                1753
# Teaching_Hospital_ID                 1753
#                                     ...
# Program_Year                            0
# Payment_Publication_Date                0
# ClinicalTrials_Gov_Identifier        6739
# Research_Information_Link            9452
# Context_of_Research                  7810
# Length: 252, dtype: int64

# %%
df = df.iloc[:, [1, 2, 3, 4, 5, 6, 7, 8, 10, 14, 15, 16, 20, 26, 233, 234, 246, 247, 248]]

# %%
df.info(file_path)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Covered_Recipient_Type             10000 non-null  object
#  1   Noncovered_Recipient_Entity_Name   0 non-null      float64
#  2   Teaching_Hospital_CCN              8247 non-null   float64
#  3   Teaching_Hospital_ID               8247 non-null   float64
#  4   Teaching_Hospital_Name             8247 non-null   object
#  5   Covered_Recipient_Profile_ID       1753 non-null   float64
#  6   Covered_Recipient_NPI              1749 non-null   float64
#  7   Covered_Recipient_First_Name       1753 non-null   object
#  8   Covered_Recipient_Last_Name        1753 non-null   object
#  9   Recipient_City                     10000 non-null  object
#  10  Recipient_State                    10000 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Covered_Recipient_Type', 'Noncovered_Recipient_Entity_Name',
#        'Teaching_Hospital_CCN', 'Teaching_Hospital_ID',
#        'Teaching_Hospital_Name', 'Covered_Recipient_Profile_ID',
#        'Covered_Recipient_NPI', 'Covered_Recipient_First_Name',
#        'Covered_Recipient_Last_Name', 'Recipient_City', 'Recipient_State',
#        'Recipient_Zip_Code', 'Covered_Recipient_Primary_Type_1',
#        'Covered_Recipient_Specialty_1', 'Total_Amount_of_Payment_USDollars',
#        'Date_of_Payment', 'Record_ID', 'Program_Year',
#        'Payment_Publication_Date'],
#       dtype='object')

# %%
 df.isnull().sum()
# Out:
# Covered_Recipient_Type                   0
# Noncovered_Recipient_Entity_Name     10000
# Teaching_Hospital_CCN                 1753
# Teaching_Hospital_ID                  1753
# Teaching_Hospital_Name                1753
# Covered_Recipient_Profile_ID          8247
# Covered_Recipient_NPI                 8251
# Covered_Recipient_First_Name          8247
# Covered_Recipient_Last_Name           8247
# Recipient_City                           0
# Recipient_State                          0
# Recipient_Zip_Code                       0
# Covered_Recipient_Primary_Type_1      8247
# Covered_Recipient_Specialty_1         8247
# Total_Amount_of_Payment_USDollars        0
# Date_of_Payment                          0
# Record_ID                                0
# Program_Year                             0
# Payment_Publication_Date                 0
# dtype: int64

# %%
df['Recipient_Zip_Code'] = df['Recipient_Zip_Code'].astype(str).str[:5]

# %%
print(df['Recipient_Zip_Code'])
# Out:
# 0       48201
# 1       45229
# 2       61761
# 3       90033
# 4       48202
#         ...
# 9995    14642
# 9996    48374
# 9997    52242
# 9998    95616
# 9999    37232
# Name: Recipient_Zip_Code, Length: 10000, dtype: object

# %%
df['Total_Amount_of_Payment_USDollars'] = df['Total_Amount_of_Payment_USDollars'].round(2)

# %%
print(df['Total_Amount_of_Payment_USDollars'])
# Out:
# 0       31951.26
# 1         259.06
# 2        1062.50
# 3        1250.00
# 4        2821.05
#           ...
# 9995       30.85
# 9996      140.00
# 9997     6475.00
# 9998     7500.00
# 9999     3500.00
# Name: Total_Amount_of_Payment_USDollars, Length: 10000, dtype: float64

# %%
df.fillna("Not available", inplace=True)

# %%
df
# Out:
#                    Covered_Recipient_Type Noncovered_Recipient_Entity_Name  \
# 0     Covered Recipient Teaching Hospital                    Not available
# 1     Covered Recipient Teaching Hospital                    Not available
# 2     Covered Recipient Teaching Hospital                    Not available
# 3     Covered Recipient Teaching Hospital                    Not available
# 4     Covered Recipient Teaching Hospital                    Not available
# ...                                   ...                              ...
# 9995  Covered Recipient Teaching Hospital                    Not available
# 9996  Covered Recipient Teaching Hospital                    Not available
# 9997  Covered Recipient Teaching Hospital                    Not available
# 9998  Covered Recipient Teaching Hospital                    Not available
# 9999  Covered Recipient Teaching Hospital                    Not available
#
#      Teaching_Hospital_CCN Teaching_Hospital_ID  \
# ...

# %%
df.info(file_path)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Covered_Recipient_Type             10000 non-null  object
#  1   Noncovered_Recipient_Entity_Name   10000 non-null  object
#  2   Teaching_Hospital_CCN              10000 non-null  object
#  3   Teaching_Hospital_ID               10000 non-null  object
#  4   Teaching_Hospital_Name             10000 non-null  object
#  5   Covered_Recipient_Profile_ID       10000 non-null  object
#  6   Covered_Recipient_NPI              10000 non-null  object
#  7   Covered_Recipient_First_Name       10000 non-null  object
#  8   Covered_Recipient_Last_Name        10000 non-null  object
#  9   Recipient_City                     10000 non-null  object
#  10  Recipient_State                    10000 non-null  object
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a correlation matrix
corr_matrix = df.corr()

# Create a heatmap using seaborn
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')

# Show the plot
plt.show()

# %%
df.boxplot(figsize = (15,15))
# Out:
# <AxesSubplot: >

# %%
df.hist(figsize = (15,15))
# Out:
# array([[<AxesSubplot: title={'center': 'Total_Amount_of_Payment_USDollars'}>,
#         <AxesSubplot: title={'center': 'Record_ID'}>],
#        [<AxesSubplot: title={'center': 'Program_Year'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
#check for outliers and remove
from scipy import stats

print(df.shape)
df = df[(np.abs(stats.zscore(df.select_dtypes(include=np.number))) < 3).all(axis=1)]
print(df.shape)
# Out:
# (10000, 19)
# (0, 19)

# %%
#Save to new file 
df.to_csv('2021ResearchPaymentData_prepared.csv')
